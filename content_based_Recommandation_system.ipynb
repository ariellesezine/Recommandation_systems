# %% [markdown]
# # systeme de recommandation pour une plateforme de cours en ligne par SEZINE Arielle
#
# # type de systeme: content based/ basé sur le contenu
#
# ##### Un système de recommandation (SR) basé sur le contenu (ou content-based filtering) est un type de système de recommandation qui suggère des éléments à un utilisateur en se basant sur les caractéristiques des éléments eux-mêmes.

# %% [markdown]
# ![image_illustrative](recomandation.png)

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %% [markdown]
# #### chargement des données

# %%
data=pd.read_csv("coursera.csv")

# %% [markdown]
# ### analyse exploratoire

# %%
data.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                   Course Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               Skills
# 0  Drama  Comedy  peering  screenwriting  film  D...
# 1  Finance  business plan  persona (user experien...
# 2  chemistry  physics  Solar Energy  film  lambda...
# 3  accounts receivable  dupont analysis  analysis...
# 4  Data Analysis  select (sql)  database manageme...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Course Name         3522 non-null   object
#  1   University          3522 non-null   object
#  2   Difficulty Level    3522 non-null   object
#  3   Course Rating       3522 non-null   object
#  4   Course URL          3522 non-null   object
#  5   Course Description  3522 non-null   object
#  6   Skills              3522 non-null   object
# dtypes: object(7)
# memory usage: 192.7+ KB

# %%
data["Course Rating"].value_counts()
# Out:
# Course Rating
# 4.7               740
# 4.6               623
# 4.8               598
# 4.5               389
# 4.4               242
# 4.9               180
# 4.3               165
# 4.2               121
# 5                  90
# 4.1                85
# Not Calibrated     82
# 4                  51
# 3.8                24
# 3.9                20
# 3.6                18
# 3.7                18
# 3.5                17
# 3.4                13
# 3                  12
# 3.2                 9
# 3.3                 6
# 2.9                 6
# 2.6                 2
# 2.8                 2
# 2.4                 2
# 1                   2
# 2                   1
# 3.1                 1
# 2.5                 1
# 1.9                 1
# 2.3                 1
# Name: count, dtype: int64

# %%
data["Difficulty Level"].value_counts()
# Out:
# Difficulty Level
# Beginner          1444
# Advanced          1005
# Intermediate       837
# Conversant         186
# Not Calibrated      50
# Name: count, dtype: int64

# %% [markdown]
# #### compte tenu de l'usage que nous ferons de notre systeme de recommandation, nous devons supprimer les colonnes:
# - university parceque une université peut dispenser une infinité de cours n'ayant rien a voir les uns avec les autres
# - Course Rating : dans un SR basé sur le contenu la notation n'est d'aucune utilité
# - Course URL : n'apporte pas d'information importante

# %% [markdown]
# ### Preprocessing : apres la suppression des colonnes surcitées nous allons effectuer les operations suivante
# - creer une nouvelle colonne appelée tag qui contiendra les potentiels mots clés d'une recherche: elle contiendra a la fois le nom du cours, le niveau de difficulté et competences pour un cours donnée
# - supprimer les stopwords dans la colonne tag afin de diminuer les informations inutiles
# - la lemmatisation pour reduire des mots  à sa forme de base
# - la vectorisation pour mettre nos texte sous formes comprehensible par la machine

# %% [markdown]
# #### Suppression des colonnes inutiles

# %%
data.drop(columns=['University','Course Rating','Course URL'], inplace=True)

# %%
data.columns
# Out:
# Index(['Course Name', 'Difficulty Level', 'Course Description', 'Skills'], dtype='object')

# %% [markdown]
# ###### nous allons definir ensuite une colonne qui sera utiliser pour calculer les similarités

# %%
#remplacement des ponctuations par des espaces
def formating_col(col_name):
    elt=[]
    for i in range(data.shape[0]):
        a=re.sub(r'[^\w\s]', ' ',data[col_name][i])
        a=a.lower()
        elt.append(a)
    
    return elt

# %%
data['Course Description']=formating_col(col_name= 'Course Description')
data['Skills']=formating_col(col_name= 'Skills')
data['Course Name']=formating_col(col_name= 'Course Name')
data['Difficulty Level']=formating_col(col_name= 'Difficulty Level')

# %%
data
# Out:
#                                             Course Name Difficulty Level  \
# 0     write a feature length screenplay for film or ...         beginner
# 1     business strategy  business model canvas analy...         beginner
# 2                         silicon thin film solar cells         advanced
# 3                                  finance for managers     intermediate
# 4          retrieve data using single table sql queries         beginner
# ...                                                 ...              ...
# 3517  capstone  retrieving  processing  and visualiz...         beginner
# 3518                   patrick henry  forgotten founder     intermediate
# 3519  business intelligence and data analytics  gene...         advanced
# 3520                                rigid body dynamics         beginner
# 3521  architecting with google kubernetes engine  pr...     intermediate
#
#                                      Course Description  \
# 0     write a full length feature film script  in th...
# 1     by the end of this guided project  you will be...
# 2     this course consists of a general presentation...
# 3     when it comes to numbers  there is always more...
# 4     in this course you ll learn how to effectively...
# ...                                                 ...
# 3517  in the capstone  students will build a series ...
# 3518   give me liberty  or give me death   rememberi...
# 3519   megatrends  heavily influence today s organis...
# 3520  this course teaches dynamics  one of the basic...
# 3521  in this course   architecting with google kube...
#
#                                                  Skills
# 0     drama  comedy  peering  screenwriting  film  d...
# 1     finance  business plan  persona  user experien...
# 2     chemistry  physics  solar energy  film  lambda...
# 3     accounts receivable  dupont analysis  analysis...
# 4     data analysis  select  sql   database manageme...
# ...                                                 ...
# 3517  databases  syntax  analysis  web  data visuali...
# 3518  retirement  causality  career  history of the ...
# 3519  analytics  tableau software  business intellig...
# 3520  angular  mechanical design  fluid mechanics  f...
# 3521  bigtable  bigquery  sql  google cloud platform...
#
# [3522 rows x 4 columns]

# %%
# concatenation des lignes entres elles pour creer une colone tag
data["tags"]=data['Course Name']+data['Skills']+data['Course Description']

# %%
data
# Out:
#                                             Course Name Difficulty Level  \
# 0     write a feature length screenplay for film or ...         beginner
# 1     business strategy  business model canvas analy...         beginner
# 2                         silicon thin film solar cells         advanced
# 3                                  finance for managers     intermediate
# 4          retrieve data using single table sql queries         beginner
# ...                                                 ...              ...
# 3517  capstone  retrieving  processing  and visualiz...         beginner
# 3518                   patrick henry  forgotten founder     intermediate
# 3519  business intelligence and data analytics  gene...         advanced
# 3520                                rigid body dynamics         beginner
# 3521  architecting with google kubernetes engine  pr...     intermediate
#
#                                      Course Description  \
# 0     write a full length feature film script  in th...
# 1     by the end of this guided project  you will be...
# 2     this course consists of a general presentation...
# 3     when it comes to numbers  there is always more...
# 4     in this course you ll learn how to effectively...
# ...                                                 ...
# 3517  in the capstone  students will build a series ...
# 3518   give me liberty  or give me death   rememberi...
# 3519   megatrends  heavily influence today s organis...
# 3520  this course teaches dynamics  one of the basic...
# 3521  in this course   architecting with google kube...
#
#                                                  Skills  \
# 0     drama  comedy  peering  screenwriting  film  d...
# 1     finance  business plan  persona  user experien...
# 2     chemistry  physics  solar energy  film  lambda...
# 3     accounts receivable  dupont analysis  analysis...
# 4     data analysis  select  sql   database manageme...
# ...                                                 ...
# 3517  databases  syntax  analysis  web  data visuali...
# 3518  retirement  causality  career  history of the ...
# 3519  analytics  tableau software  business intellig...
# 3520  angular  mechanical design  fluid mechanics  f...
# 3521  bigtable  bigquery  sql  google cloud platform...
#
#                                                    tags
# 0     write a feature length screenplay for film or ...
# 1     business strategy  business model canvas analy...
# 2     silicon thin film solar cellschemistry  physic...
# 3     finance for managersaccounts receivable  dupon...
# 4     retrieve data using single table sql queriesda...
# ...                                                 ...
# 3517  capstone  retrieving  processing  and visualiz...
# 3518  patrick henry  forgotten founderretirement  ca...
# 3519  business intelligence and data analytics  gene...
# 3520  rigid body dynamicsangular  mechanical design ...
# 3521  architecting with google kubernetes engine  pr...
#
# [3522 rows x 5 columns]

# %% [markdown]
# #### Suppression des stopwords dans la description des données:
# - Les stopwords sont des mots courants dans une langue qui sont souvent filtrés et ignorés dans les tâches de traitement du langage naturel (NLP) et d'analyse de texte. Ils ne portent généralement pas beaucoup d'information significative par eux-mêmes et peuvent donc être considérés comme non pertinents pour certaines analyses, telles que la classification de texte ou l'extraction d'informations.
#
# - En anglais, les stopwords courants incluent des mots tels que :"the","is","in","and","of","to" ; la liste est non exhaustive

# %%
tags=[]
for i in range(data.shape[0]):
    elt=[word for word in data['tags'][i].split(" ") if word not in stopwords.words('english')]
    elt=" ".join(elt)
    tags.append(elt)   
tags
# Out:
# ['write feature length screenplay film televisiondrama  comedy  peering  screenwriting  film  document review  dialogue  creative writing  writing  unix shells arts humanities music artwrite full length feature film script  course  write complete  feature length screenplay film television  serious drama romantic comedy anything  learn break creative process components  discover structured process allows produce polished pitch ready script end course  completing project increase confidence ideas abilities  feel prepared pitch first script get started next  course designed tap creativity based  active learning   actual learning takes place within activities    writing  learn   link trailer course  view trailer  please copy paste link browser  https   vimeo com 382067900 b78b800dc0  learner review   love approach professor wheeler takes towards course  point  easy follow  informative  would definitely recommend anyone interested taking screenplay writing course   course curriculum simple  adopt professional writers room process write  post work peer review  share feedback peers revise work feedback receive peers  real world  feel professional writers room yet prior experience writer required  proponent experiential learning  active learning   lectures short  sometimes two minutes long  point  designed step step process essential success script writer  guide  show  write  firmly believe way become writer write  write  write   learner review   would like thank course instructor  amazing course   need get started  mentioned  prior script writing experience required  begin  basic word processor  week two  choose download free scriptwriting software celtx trelby may choose purchase final draft  industry standard  continue use word processor script formatting    learner review   writer    concerns regarding protection original work  coursera privacy policy protects learner ip indeed sole owners work ',
#  'business strategy  business model canvas analysis mirofinance  business plan  persona  user experience   business model canvas  planning  business  project  product development  presentation  strategy business business strategyby end guided project  fluent identifying creating business model canvas solutions based previous high level analyses research data   enable identify map elements required new products services  furthermore  essential generating positive results business venture  guided project designed engage harness visionary exploratory abilities  use proven models strategy product development miro platform explore analyse business propositions    practice critically examining results previous analysis research results deriving values business model sections ',
#  'silicon thin film solar cellschemistry  physics  solar energy  film  lambda calculus  electrical engineering  electronics  energy  silicon  thinning physical science engineering electrical engineeringthis course consists general presentation solar cells based silicon thin films    third mooc photovoltaic series ecole polytechnique coursera  general aspects photovoltaic field treated  photovoltaic solar energy   detailed description crystalline silicon solar cells found  physics silicon solar cells    brief presentation solar cells operation  thin film semiconductors described  general properties disordered crystalline semiconductors found different  particular terms band structure doping mechanisms  silicon thin films  generally less 1  thick  deposited silane plasma leading hydrogen incorporation  growth mechanisms discussed  particular capability prepare partially crystallized thin films appear mixture nanocrystallites embedded amorphous tissue   consequences semiconductor properties solar cells behavior reviewed  optical properties amorphous nanocrystalline silicon complementary  thus plasma process particularly well adapted preparation multijunctions  conversion efficiencies around 13 15    furthermore plasma processes allow prepare solar cells large area glass flexible substrates   finally  shown crystalline amorphous silicon materials combine heterojunctions solar cells high efficiency conversion  25        course part series 3   photovoltaic solar energy  https   www coursera org learn photovoltaic solar energy   physics silicon solar cells  https   www coursera org learn physics silicon solar cells   silicon thin film solar cells',
#  'finance managersaccounts receivable  dupont analysis  analysis  accounting  finance  operations management  leadership management  balance sheet  inventory  financial analysis business financewhen comes numbers  always meets eye   operational finance  learn read  story  balance sheet income statement tells company operations  insights gain  financial story  become tool short term decision making top management level relating current assets  current liabilities management working capital  finally  end course understand financial consequences managerial decisions operations  marketing  etc ',
#  'retrieve data using single table sql queriesdata analysis  select  sql   database management systems  online shopping  table  database   data retrieval  databases  web page  numbers  spreadsheet   sql information technology data managementin course learn effectively retrieve data relational database table using sql language    know computer systems rely least one database store data  tax information stored database used internal revenue service  phone stores contacts    names  addresses  email addresses  phone numbers database  shop online  viewing photos  descriptions  prices products stored database  database designers go great lengths design databases data stored securely organized format  important note main reason go work get data back need  called  data retrieval     data retrieved read relational database using language called sql query  question  database  sql referred  language relational databases   used embedded programs retrieve data  data retrieved  displayed web page pc application  even printed paper    practicing writing sql queries using sqlitestudio    next time go online look daily special favorite restaurant  think fact likely sql query used behind scenes fetch data pop screen  end course  even pretty good idea query might looked like   note  course works best learners based north america region  currently working providing experience regions ',
#  'building test automation framework using selenium testngmaintenance  test case  test automation  screenshot  project  helper class  selenium  reusability  debugging  php computer science software developmentselenium one widely used functional ui automation testing tools testng brilliant testing framework   test automation frameworks set guidelines rules writing test cases   reduce maintenance costs testing efforts provide higher return investment  roi  teams looking optimize processes   testing guidelines include coding standards  test data management  defining object repositories  reporting guidelines  logging strategies   hands  practical experience  go concepts writing reusable structure code easy maintain understand  creating helper classes utilities  write effective testcases  generating reports logs ',
#  'business china capstonemarketing plan  planning  marketing  consumption  economics   wait  system call   business plan  strategic planning  audience  project  writing business business strategydoing business china capstone enables apply skills real business challenges  use newly earned business skills identify  explore evaluate real opportunity involving products   capstone  business consultant working well established  hon   wellness  company   ceo given task   bring new overseas product china ',
#  'programming languages  part ainference  ml  programming language   higher order function  functional programming  type inference  pattern matching  euler totient function  language    recursive function  computer programming computer science software developmentthis course introduction basic concepts programming languages  strong emphasis functional programming  course uses languages ml  racket  ruby vehicles teaching concepts  real intent teach enough language  fits together  make effective programming language    learning new ones   course neither particularly theoretical programming specifics    give framework understanding use language constructs effectively design correct elegant programs  using different languages  learn think deeply terms particular syntax one language  emphasis functional programming essential learning write robust  reusable  composable  elegant programs  indeed  many important ideas modern languages roots functional programming  get ready learn fresh beautiful way look software fun building   course assumes prior experience programming  described detail first module   course divided three coursera courses  part  part b  part c   explained detail first module part  overall course substantial amount challenging material  three part format provides two intermediate milestones opportunities pause continuing   three parts designed completed order set motivate continue end part c   three parts quite equal length  part almost substantial part b part c combined   week 1 part detailed list topics three parts course  expected course participants  yet   know topics mean ',
#  'roles responsibilities nonprofit boards directors within governance processplanning  peer review  fundraising  strategic planning  resource  concept testing  leadership  measurement  performance  evaluation business leadership managementthis course provides depth look roles responsibilities boards directors governance nonprofit organizations  course developed north american culture mind  appreciate parts world  nature roles responsibilities boards directors may  nevertheless hope much course content still value parts world    learn course  please watch overview video copying pasting following link web browser  https   goo gl sxzezs   keywords  nonprofit  nonprofit sector  voluntary sector  nonprofit organizations  non governmental organizations  volunteer organizations  leadership  management  governance  board  board directors  performance  effectiveness  course 2 overview    week 1  questions explored week  board role planning organization future important nonprofit organizations  strategic planning boards carry effectively    week 2  week questions  board role assessing performance organization  performance assessment important  many boards difficulty meeting performance assessment responsibilities    week 3  week questions  elements fundraising resource development process  board role ensuring organization adequate funding  information resource development plan    week 4  stage  asked review course content  submit written assignment  known lightheartedly bear  board effectiveness readiness assessment   take two multiple choice readiness assurance tests  known similarly rats   one rat assess knowledge reading comprehension test application knowledge within practical case     week 5  encourage discuss rats discussion forums take wish change answers based information exchanged ',
#  'business russian communication  part 3russian  market  economics   tax exemption  cooperation  communication  taxes  adjective  h e r   listening  c dynamic memory allocation language learning languagesrussian considered one difficult languages world  many learners struggle master grammar pronunciation  course aimed wants work russia  business russian partners study business related majors russian    three units intensive course learners going find discuss terms cooperationand prices  describe market situation make successful presentation companies  goods services  course third part business russian communication series courses offered st petersburg state university  part introduces grammar topics numerals nouns genitive case  genitive case prepositions  verbs motion unpaired prefixes declension adjectives  learners practice skills test grammar quiz section  course provides extensive vocabulary 100 new words conversational phrases learners use everyday communication professional informal topics  unit course contains dialogues  extremely useful wants listen original russian speech get used pace intonations russian language  scripts exercises provided dialogues course  end course learners chance use material leant assess progress preparing final assignment  course aimed already achieved a2 a2  level russian ',
#  'agile projects   developing tasks taigaproject  modeling  project management  agile management  user story  presentation  product development  leadership management  documents  web design business business strategyby end guided project  fluent creating tasks agile projects based previous project phases  enable identify   customer user experience product service  learn encapsulate value customer tasks    essential generating positive results business venture  furthermore  guided project designed engage harness visionary exploratory abilities  use proven models agile project management taiga shape development roadmap products services    practice critically defining user stories become valuable tasks creating functionality products services ',
#  'esports management capstone projectaverage  planning  leadership management  peer review  strategy  peering  evaluation  recruiting  project  interest business leadership managementwe analyze pros cons creating single multiple esport organization recommend effective branding strategy hypothetical esport organization based current esport branding considerations  develop plan recruiting funding resources hypothetical esports organization choose esport organization role interest  owner  describe reasoning ',
#  'hacking patchingsecurity design  design pattern  web application  internet security  sql  select  sql   metasploit project  penetration test  security  password cracking computer science computer security networksin mooc  learn hack web apps command injection vulnerabilities web site aws linux instance    learn search valuable information typical linux systems lamp services  deposit hide trojans future exploitation   learn patch web apps input validation using regular expression  learn security design pattern avoid introducing injection vulnerabilities input validation replacing generic system calls specific function calls   learn hack web apps sql injection vulnerabilities retrieve user profile information passwords   learn patch input validation sql parameter binding   learn hacking methodology  nessus tool scanning vulnerabilities  kali linux penetration testing  metasploit framework gaining access vulnerable windows systems  deploying keylogger  perform remote vnc server injection   learn security memory systems virtual memory layout  understand buffer overflow attacks defenses   learn clone kali instance aws p2 gpu support perform hashcat password cracking using dictionary attacks known pattern mask attacks ',
#  'business statistics analysis capstonestatistical analysis  microsoft excel  business analytics  regression analysis  general statistics  data analysis  regression  analytics  analysis  business analysis data science data analysisthe business statistics analysis capstone opportunity apply various skills developed across four courses specialization real life data  capstone  collaboration industry partner uses publicly available  housing data  pose various questions typically client would pose data analyst  job relevant statistical analysis report findings response questions way anyone understand  please remember capstone  degree difficulty ambiguity higher previous four courses  aim mimic real life application close possible ',
#  'grab data fast vertical horizontal lookupevaluation  software  presentation  lookup table  spreadsheet software  benefits  spreadsheet  project  index  fasting business business essentialsdata come way multiple forms multiple file types  likely point faced data set includes categories subcategories one heading headings nested subheadings  cutting file structure seem like time consuming task  critical leverage vlookup hlookup pull needed data quickly  course understand lookup tables work apply vlookup hlookup formulas quickly extract data treating section spreadsheet lookup table  work side side free use software google sheets   end course  understand use cases using vertical horizontal lookup extract data data sets categories configured multiple levels  also able confidently apply vlookup hlookup formulas grab data spreadsheet software    note  course works best learners based north america region  currently working providing experience regions ',
#  'global health  interdisciplinary overviewsustainability  research development  communication  health system  leadership management  health research  global  disease  drug development  public health life sciences public healththis course proposes overview current global health challenges drawing insights several academic disciplines including medicine  public health  law  economics  social sciences humanities  interdisciplinary approach guide student seven critical topics global health ',
#  'python programming essentialssemantics  python programming  coding conventions  codeskulptor  problem solving  syntax  computer programming  programming style  python syntax semantics  euler totient function computer science software developmentthis course introduce wonderful world python programming   learn essential elements programming construct basic python programs  cover expressions  variables  functions  logic  conditionals  foundational concepts computer programming  also teach use python modules  enable benefit vast array functionality already part python language  concepts skills help begin think like computer programmer understand go writing python programs   end course  able write short python programs able accomplish real  practical tasks  course foundation building expertise python programming  first course specialization  provides necessary building blocks succeed learning write complex python programs   course uses python 3   many python programs continue use python 2  python 3 future python programming language  first course use python 3 version codeskulptor development environment  specifically designed help beginning programmers learn quickly   codeskulptor runs within modern web browser require install software  allowing start writing running small programs immediately   later courses specialization   help move sophisticated desktop development environments ',
#  'creating dashboards storytelling tableauneuroscience  data visualization  storytelling  tableau software  business analytics  checklists  software  method analytic tableaux  javascript syntax  audience data science data analysisleveraging visualizations created previous course  visual analytics tableau  create dashboards help identify story within data  discover use storypoints create powerful story leave lasting impression audience   balance goals stakeholders needs end users  able structure organize story maximum impact  throughout course apply advanced functions within tableau  hierarchies  actions parameters guide user interactions   final project  create compelling narrative delivered meeting  static report  interactive display online ',
#  'parallel programmingdata structures  parallel algorithm  openfabrics alliance  task parallelism  unified parallel c  algorithms  data parallelism  scala programming  parallel computing  computer programming computer science software developmentwith every smartphone computer boasting multiple processors  use functional ideas facilitate parallel programming becoming increasingly widespread  course  learn fundamentals parallel programming  task parallelism data parallelism  particular  see many familiar ideas functional programming map perfectly data parallel paradigm  start nuts bolts effectively parallelize familiar collections operations  build parallel collections  production ready data parallel collections library available scala standard library  throughout  apply concepts several hands examples analyze real world data  popular algorithms like k means clustering   learning outcomes  end course able     reason task data parallel programs    express common algorithms functional style solve parallel    competently microbenchmark parallel code    write programs effectively use parallel collections achieve performance  recommended background  least one year programming experience  proficiency java c  ideal  experience languages c c    python  javascript ruby also sufficient  familiarity using command line  course intended taken functional program design scala  https   www coursera org learn progfun2 ',
#  'recommendation systems tensorflow gcpsystems architecture  cloud computing  google cloud platform  tensorflow  deep learning  cloud platforms  machine learning  matrices  artificial neural networks  recommender systems data science machine learningin course  apply knowledge classification models embeddings build ml pipeline functions recommendation engine     devise content based recommendation engine   implement collaborative filtering recommendation engine   build hybrid recommendation engine user content embeddings      enrolling course agree qwiklabs terms service set faq located  https   qwiklabs com terms_of_service    ',
#  'changing arctichuman learning  geology  curiosity  methane  problem solving  plant  biologist  resource  dam  volatile organic compound life sciences basic sciencewhat learn  taking course understanding arctic landscapes  formed changing  also learn scientists countries around north working together understand changes affect people north global community  experience range scientific topics  date methods understanding environment  current consensus views future arctic environment   need prior knowledge  prior knowledge needed course  participants come equipped natural curiosity willingness invest time understanding environmental issue global concern  terms concepts targeted educated public  specialists  resources provided motivated explore issues depth ',
#  'covid 19   clinical updatedisease  mechanical ventilation  vaccine  outbreak  epidemic  medical history  intubation  epidemics  patient  social distancing life sciences patient careas expert infectious diseases  editor journal infectious diseases author textbook infectious diseases  clinical short course  mcgraw hill april 2020  concerned misinformation shared covid 19 epidemic  disease develop  come  cause diseases   answers questions answered first video module 1  world startled frightened rapid spread virus throughout world  video 2  epidemiology presently understood reviewed  video periodically updated recognizing rapid progression pandemic  many want know disease present  symptoms associated covid 19  dangerous covid 19  risk dying  questions answered video 3  finally disease best treated slow spread infection  questions answered video 4   addition videos multiple choice questions included test understanding epidemiology peer reviewed exercise designed teach infection spread show power tracing cases isolating infected  second peer review exercise encourage create campaign shift countries culture embrace behaviors lead suppression epidemic  behaviors save lives  completing course armed knowledge skills make difference help bend curve ',
#  'create text effects gimppointing device gesture  r management  gradient  lambda lifting  ordered pair  english grammar  top bottom design  standing ovation  path  variable   project computer science design productin 1 hour long project based course  learn add myriad text effects  learn make text stand background  add border text make text outline  learn place image inside text place gradient inside text  learn place text path make 3d text  also learn add filters text generate text effects   note  course works best learners based north america region  currently working providing experience regions ',
#  'preparing google cloud professional data engineer exambusiness requirements  cloud computing  google cloud platform  information engineering  cloud platforms  google cloud dataproc  dataflow  databases  bigquery  machine learning information technology cloud computingfrom course   best way prepare exam competent skills required job    course uses top approach recognize knowledge skills already known  surface information skill areas additional preparation  use course help create custom preparation plan  helps distinguish know know  helps develop practice skills required practitioners perform job   course follows organization exam guide outline  presenting highest level concepts   touchstones   determine whether feel confident knowledge area dependent concepts  want study  also learn opportunity practice key job skills  including cognitive skills case analysis  identifying technical watchpoints  developing proposed solutions  job skills also exam skills  also test basic abilities activity tracking challenge labs  many sample questions similar exam  including solutions  end course contains ungraded practice exam quiz  followed graded practice exam quiz simulates exam taking experience   new  certificate completion challenge unlock benefits coursera google cloud enroll complete cloud engineering google cloud cloud architecture google cloud professional certificate  data engineering google cloud professional certificate november 8  2020 receive following benefits       google cloud shirt  first 1 000 eligible learners complete  supplies last    exclusive access big    interview   950 value  career coaching     30 days free access qwiklabs   50 value  earn google cloud recognized skill badges completing challenge quests',
#  'multiple regression analysis public healthregression analysis  regression  public health  confounding  interaction  statistics   estimation  linear regression  confidence interval  odds ratio  logistic regression life sciences health informaticsbiostatistics application statistical reasoning life sciences  key unlocking data gathered researchers evidence presented scientific public health literature  course  extend simple regression prediction single outcome interest basis multiple variables  along way  introduced variety methods  practice interpreting data performing calculations real data published studies   topics include multiple logistic regression  spline approach  confidence intervals  p values  multiple cox regression  adjustment  effect modification ',
#  'general pathophysiologymedicine  biomedical sciences  microcirculation  physiology  endocrinology  biochemistry  inflammations  pathophysiology  pathology  internal medicine life sciences basic sciencedear listeners   warning  course contains shocking materials recommended viewing persons weak psyche  minors pregnant women   course describes subject methods pathophysiology  place within system biomedical sciences history   includes general nosology  concept health disease  general etiology pathogenesis  pathological processes states  role causal factors  conditions  reactivity somatotype pathology   gives systematic locally centrally driven typical pathological processes  arterial  venous combined hyperemiae  stasis  inflammation  immunopathological processes  including allergy autoimmune disorders  acute phase response  fever  stress  shock  etc  course deals functional  metabolic informational aspects typical pathologic processes  like disorders signaling  reception  post   receptor translation  programming program archiving  conflicts programs living systems  contains consequent analysis injury defensive responses regards separate cells  organs tissues whole organism  lectures based author original three volumed textbook workshop pathophysiology republished russia many times ',
#  'population health  alternative payment modelsincentive  behavioral economics  loss aversion  modeling  enabling  relative change difference  financial accounting  desire  payments  risk life sciences healthcare managementthe way currently pay care providers lead suboptimal outcomes unnecessary spending  consequently  fail maximize value health care services  need change provider payment models order keep health care systems financial sustainability  nothing option  question     course  discuss rationale payment reforms dive key design elements alternative payment models  apms  change care provider incentives  learn roadmap design implement apms  learn behavioural economics human behaviour essential advance design implementation apms  course apply sharpened skills lead change health care via innovative payment models order increase value health care services   course targeted variety professionals healthcare sector order realise common language  provider  board member  working public private payer researcher working health sector  course relevant   course part developed leiden university master program population health management  wish find program see last reading course ',
#  'aws elastic beanstalk  build   deploy node js restful apirepresentational state transfer  uniform resource locator  cloud computing  web application  ordered pair  hypertext transfer protocol  virtual private server  web  application programming interfaces  switches information technology cloud computingin 1 hour long project based course  learn create node js restful api   launch server using aws elastic beanstalk technology  using express js  simply express  back end web application framework node js framework create restful api   aws desktop management console deploy restful api aws servers  additionally  learn reading server logs  switch different versions api applications   also  monitoring aws servers using elastic beanstalk management console   note  avoid distraction set course  would recommend create amazon aws account beforehand  amazon aws provides free tier option 1 year   course materials utilize services fall free tier option ',
#  'philosophy  science religion  philosophy religionordered pair  arts humanities  virtue  spirituality  philosophy  cognitive science  bible  belief  religion  evolution arts humanities philosophyphilosophy  science religion mark three fundamental modes thinking world place  modes incompatible  put another way  intellectually responsible thing  pick sides  identify one approaches exclusion others   complementary mutually supportive  typical questions magnitude  devil details  example  important work really distinctive ways inquiring world  order gain clarity  investigating current leading thinkers philosophy  science religion actually   course  entitled  philosophy religion   second three related courses philosophy  science religion online series  course ask important questions age old debate science religion        kind conflicts religion science     current cognitive science religion effectively explain away god     god made us know  people believe     belief science also kind fundamentalism     makes us good getting  giving  sharing  knowledge  different religious knowledge   first course philosophy  science religion series   science philosophy  launched early 2017 sign time  third course   religion science  launched early 2018  completing three courses give broader understanding fascinating topic  look      philosophy  science religion  science philosophy https   www coursera org learn philosophy science religion 1    philosophy  science religion iii  religion science  upon successful completion three courses  students    1  understand main parameters stake current debate science religion   2  familiarity relevant areas science feature debate including cosmology  evolution  neurosciences begun engage conceptually   3  encountered key philosophical approaches interface science religion  opportunity engage practice   4  embarked constructively cross disciplinary conversations   5  demonstrated openness personal growth commitment dialogue across intellectual spiritual boundaries   also follow us twitter https   twitter com ediphilonline follow hashtag  psrmooc',
#  'poverty   population  demographics shape policyeducation  billing  political science  oppression  population  inflation  unemployment  market  economics   demography  social work social sciences governance societythis course four modules  foci   first understand categories social welfare populations  income  earnings  assets  related concepts play large role shaping policy decisions  unemployment  inflation  minimum wage   second deals central institution social welfare labor market  largely determines many resources person   labor market also establishes hierarchy  meritocracy categories privilege   third poverty  differing ways define poor  effective u  anti poverty efforts   final module looks directly federal decision making  political organization ideas  structure u  government  legislative process shapes much social policy  course addresses issues power  oppression  white supremacy   course part sequence social policy honors track  track prepare learner masters level work policy  involves reading literature  writing concise summaries probing critiques  sequence learner develop policy analysis create foundation professional policy analyst assignments ',
#  'electrodynamics  analysis electric fieldscolloid  chemical engineering  electronics  equipotential  high voltage  physics  physics experiments  electrical engineering  studentized residual  energy physical science engineering electrical engineeringthis course continuation electrodynamics  introduction   cover different methods calculating electric field  addition  introduce polarization  dielectrics  electric fields create dipoles    learners    tbe able apply symmetry tools calculate electric field    tunderstand susceptibility  polarization  dipoles   additionally  students learn visualize maxwell equations order apply derived mathematics fields  heat mass diffusion meso scale electromechanical properties  create patents could lead potential innovations energy storage harvesting  approach taken course complements traditional approaches  covering fairly complete treatment physics electricity magnetism  adds feynman unique vital approach grasping picture physical universe  furthermore  course uniquely provides link knowledge electrodynamics practical applications research materials science  information technology  electrical engineering  chemistry  chemical engineering  energy storage  energy harvesting  materials related fields ',
#  'music american english pronunciationreceiving  english grammar  translation  data clustering algorithms  speech  music  grammar  stress  english language  phonetics language learning learning englishin third course pronunciation american english specialization  learn practice  music  american english  features pronunciation stress  rhythm  intonation help improve listening comprehension well ability communicate clearly  week receive practical advice successful english learners practice effective technique called shadowing improve pronunciation musical features english   also opportunities record respond recordings learners   learners pay course able take graded quizzes submit assignments feedback  free version provides access lectures practice activities ',
#  'fundamentals managementcontrol  management   planning  process  leadership management  management theory  process management  leadership  management process  change management  organizing  management  business leadership managementare enter workforce  emerging professional  new role organization  prospective new employees benefit understanding management principles  roles responsibilities  regardless position   acquire depth understanding basic concepts theories management exploring manager operational role types organizations  gain insight manager responsibility planning  organizing  leading  staffing controlling within workplace  never soon plan professional path learning best managers manage success   upon completing course  able  1        describe difference managers leaders 2        explore focus manager job 3        cite required skills new manager success 4        describe five functions management 5        explain new model management operating philosophy 6        describe hierarchy planning 7        use smart goal setting technique 8        discuss concept evolution leadership 9        explain customer satisfaction linked controlling 10      discuss power building network',
#  'advanced speaking listening projectproject  rapid serial visual presentation  panel discussion  critical thinking  listening  speech  english language  language learning  presentation  language language learning learning englishlearners present well organized academic speech topic academic field learner choice  learner need recall skills learned previous three courses complete several steps complete project  learner choose academic topic need research  interview couple experts field  create visual elements  record video presentation  presenter use techniques preparing practicing presentation demonstrate effective verbal non verbal skills  help prepare presentations school work ',
#  'hybrid cloud service mesh anthosauthentication  multiplexed transport layer security  service management  authorization  service discovery  load balancing  application layer  access control  intelligent network  traffic management information technology cloud computingthis demand course equips students understand adopt istio based service mesh anthos centralized observability  traffic management  service level security ',
#  'dealing missing dataestimation  weighting  population control  sample size determination  surveying  missing data  stata  regression  coverage error  sampling frame data science data analysisthis course cover steps used weighting sample surveys  including methods adjusting nonresponse using data external survey calibration   among techniques discussed adjustments using estimated response propensities  poststratification  raking  general regression estimation   alternative techniques imputing values missing items discussed   weighting imputation  capabilities different statistical software packages covered  including r   stata   sas  ',
#  'cobol programming vscodeibm cobol  numbers  spreadsheet   relative change difference  computer programming  data type  cobol  reserved word  arithmetic  mainframe  continuous function computer science software developmentprofessor tak auyeung american river college  said beautifully   programming language fashion statement  used purpose  whether add new features  modify logic  create apis integrate applications  implement modern development practices  businesses around world need application developers know cobol   introductory cobol course helps novice learn structure cobol programs  data types   variable handling  intrinsic functions  branching logic  goal course enable participant able write basic cobol programs  fantastic compliment ibm z os practitioner path ibm mainframe   join cobol fridays web series  webinars curated first time programmers  lifelong learners  anyone interested learning cobol  http   ibm biz cfcoursera  successful completion course  learners eligible earn cobol programming vscode badge ',
#  'cryptography hashing overviewaverage  cryptography  encryption  hash function  public key cryptography  string  computer science   verification validation  hashing  password  blockchain computer science algorithmscontinue learning blockchain technology diving nature ownership blockchain one way approach decentralized transaction handling  course also demystifies cryptography hashing  critical authenticating users guaranteeing transaction privacy   course requires purchase two books completion assignments   drescher    2017   blockchain basics  non technical introduction 25 steps   isbn 13  978 1484226032  antonoupoulos     2017   internet money  volume two   isbn 13  978 1947910065 ',
#  'postman   intro apis  without coding project mine  marketing  news  network news transfer protocol  project  writing  application programming interfaces  uniform resource locator  numbers  spreadsheet   interact information technology data managementwe use apis everyday   check news  log online service   apis used many companies way interact product service  able understand send api requests helpful many roles across business   including product  marketing data  work alongside interact apis job  want use apis tech data projects  course great introduction interacting apis without writing could  using program called postman   end project  understand apis used  interacted number apis  recognise different parts make api  feel comfortable reading api documentation writing requests ',
#  'protecting business innovations via patentservice innovation  innovation  patent law  intellectual property  ordered pair  law  utility  planning  business process  cost business business strategyprotecting business innovations via patent  watch course overview   https   youtu muja4iwbrte  course assumes prior knowledge law  business engineering   however  students backgrounds three areas find useful concepts ideas course protect business innovations using patents   approach taken course practical commercial rather theoretical  combination lectures case studies help illustrate concepts make course interesting      completing course  students able understand patents issued protect innovations  including  patent  protect  get patent  patents valid  much cost    addition basic concepts course also deals advanced topics  software patents  business process patents  patenting life  patent trolls multiple case examples large small companies using patents patent lawsuits    also expect fun course   go forth enjoy   courses protecting business innovations series  1  copyright      https   www coursera org learn protect business innovations copyright 2  trademark   https   www coursera org learn protect business innovations trademark  3  patent           https   www coursera org learn protect business innovations patent 4  strategy        https   www coursera org learn protect business innovations strategy',
#  'real time ocr text detection tensorflow  opencv tesseractimage processing  openbsd  optical character recognition  digital image processing  python programming  tensorflow  region interest  object detection  opencv  machine learning data science machine learningin 1 hour long project based course  learn collect label images use train tensorflow cnn  convolutional neural network  model recognize relevant areas  typeface  text image  video frame frame webcam video  learn extract image segments detector identified containing text enhance using various image filters opencv module  learn pass result image google open source ocr  optical character recognition  software using pytesseract python library read text whatever form output like    done windows  accomplished little alteration linux well  using idle development environment write single script scan video  webcam input  array images text read text output  tensorflow  tensorflow object detection api  tesseract  pytesseract library  labelimg image annotation  opencv  required software already installed rhyme desktop   note  course works best learners based north america region  currently working providing experience regions ',
#  'global strategy  global economy worksrelative change difference  economy  competitiveness  case study  analysis  foreign direct investment  trading  economic models  emerging markets  global business business strategystarting late 1990s   globalization  became buzzword describe apparent integration markets world economy  many authors pundits claimed world converging towards market friendly democratic place  gurus consulting firms short formulae advice make profits global economy  decades later  new realities show globalization mean political  cultural  economic convergence forces strong   course seeks help understand forces globalization cross cultural management relationship multinational organization various host countries becoming critical today global economy  course begins discussion issues global relationships delves deeper understanding business strategy today global business marketplace   upon successful completion course  able    tunderstand got matters   tunderstand complexities current globalization  countries    tevaluate effects international trade regulations international business   tevaluate operate multinationals  course part imba offered university illinois  flexible  fully accredited online mba incredibly competitive price  information  please see resource page course onlinemba illinois edu ',
#  'disability inclusion education  building systems supportsocial justice  special education  learning disability  education  empowerment  intellectual disability  learning disabilities  causality  teaching  child psychology social sciences educationworldwide millions children able fully participate schooling  especially problem children disabilities  course  explore support teachers need order meet needs children severe profound hearing  visual intellectual disabilities   consider done talking range experts  teachers activists  inclusive education well sharing experiences education    inclusive education possible teachers supported empowered make curriculum accessible learners  topics course cover developing disability confidence exactly children specific impairments need able learn  includes sharing specific classroom strategies teaching activities learners deaf hard hearing  blind low vision severe profound intellectual disability  end course  familiar impairment specific needs learners disabilities  build systems support inclusive education   able purchase verified certificate wish show evidence achievements  optional  may apply financial aid unable pay certificate fee   course developed part project  strengthening teaching children profound hearing  visual intellectual disabilities south africa  co funded christoffel blinden mission  cbm  european union ',
#  'introduction cybersecurity tools   cyber attackscyber security regulation  cyber security standards  forensics  security  digital forensics  cybercrime  cryptography  cyberattacks  leadership management  penetration test information technology cloud computingthis course gives background needed understand basic cybersecurity   learn history cybersecurity  types motives cyber attacks knowledge current threats organizations individuals   key terminology  basic system concepts tools examined introduction cybersecurity field   learn critical thinking importance anyone looking pursue career cybersecurity   finally  begin learn organizations resources research cybersecurity issues modern era   course intended anyone wants gain basic understanding cybersecurity first course series courses acquire skills work cybersecurity field jr cybersecurity analyst   completion course also makes eligible earn introduction cybersecurity tools   cyber attacks ibm digital badge   information badge found https   www youracclaim com org ibm badge introduction cybersecurity tools cyber attacks  want see good career fit   ibm collaborating myinnergenius  one world leading assessment companies  help find careers love    careers great match    regardless education experience    even never considered role     less hour  receive targeted recommendations hot roles excel everything need get started  even earn ibm digital badges show world skills   find http   ibm myinnergenius com ',
# ...
#  'international marketing entry executioninnovation  marketing  target market  promotion  marketing   marketing mix  social marketing  interview  strategy  consumer behaviour  global marketing business marketingthis part 2 two series foundation courses specialization  international marketing   cross industry growth  course dive deeply consumer science investigation  b2c marketing  international marketing entry  targeting  positioning  international product  international promotion  international place international price  last set classes discuss seven new ways innovate international marketing start letter   hence called 7s international marketing innovation  heavy emphasis companies incorporate ccci innovation  e  cross country cross industry innovation marketing   successfully complete course learners obtain following outcomes    1  business consumer standpoint  b2c   learn approach consumers science investigators   2  understanding enter international markets  select targets position brands   3  achieve deeper insights core meaning international marketing elements  e  product  promotion  place  price international marketing context  inter element relationships   4  acquire new thinking innovating marketing 7s approach  social  small  simple  skip  sports  screen  set marketing cross country cross industry innovation implications ',
#  'law time covid 19  northwestern teach outbusiness law  criminal justice  disease surveillance  medical law  legal support  justice  law  contact tracing  labour law  authority social sciences lawthe covid 19 crisis raises number important legal issues  matter federal authority  growing principally white house orders  looms large  actions governors local authorities especially critical  emergency shelter place important regulations directed individuals businesses  health care strategies  telemedicine  decisions food   drug administration prompt specialized legal considerations  person person level  many matters legal duty liability arise  emerging contracts  insurance  employment relations   even disease curve flattens  legal issues persist  example  necessity testing tracing infected individuals raises difficult issues privacy government engages surveillance continues strategies control  teach opportunity explore together law impacts impacted events unfold around us   free teach begin monday  april 27th run four weeks  attempt stay current possible  releasing course materials rolling basis week ',
#  'mastering bitumen better roads innovative applicationscivil engineering  hydraulics  specification  technical standard   roofing  chemistry  relative change difference  transportation engineering  road construction  fracture mechanics   properties physical science engineering chemistryduring four coming weeks  best experts bitumen bring knowledge experience build strong understanding today realities new perspectives future bitumen   total european leader bitumen markets  innovation always key sustainability durability products develop  main objective share technical knowledge experience insure bitumen used effective efficient ways different applications road works   ecole des ponts  france oldest engineering school  remains much present  always  training engineers order meet needs society citizens key areas transport housing urban services  also fields like energy  environment  climate sciences  land use planning sustainable development   nineteen world recognized experts bitumen contributing mooc   idea provide broadest prism topic area speakers coming research  industry end users ',
#  'engineering life  synbio  bioethics   public policydna  human subject research  bioethics  synthetic biology  risk benefit ratio  biotechnology  recombinant dna  biosafety  biofuel  biology life sciences public healthsynbio diverse field diverse applications  different contexts  e g   gain function research  biofuels  raise different ethical governance challenges  objective course increase learners  awareness understanding ethical policy governance issues arise design  conduct application synthetic biology  course begin short history recombinant dna technology governance science developed evolved  progress series areas application synbio    content presented many forms  including reading lectures  also recorded live interviews discussions scientists  ethicists policy makers  learners opportunity think  write talk issues challenges work real life case examples  final project engage students development governance models synbio ',
#  'customer centric strategyleadership  customer satisfaction  customer service  modeling  business model canvas  microsoft excel  technology strategy  systems design  digital marketing  problem solving business business essentialsnow ever  corporations investing heavily  quality investments affect daily work millions  yet uncommon see industry surveys failure rates projects 50   possible better possible consistently  two week course  step major challenges within corporate address disciplined use design thinking  lean startup  agile team framework    end course  developed darden school business university virginia taught top ranked faculty  able   use business model canvas focus company strategy facilitate buy stakeholders translate work canvas specific charters rapidly prototype strategically aligned processes implementation within infrastructure  please note  short form course  two weeks duration ',
#  'neural networks deep learningdeep learning  regression  human learning  backpropagation  supply chain  python programming  computer programming  artificial neural networks  logistic regression  numpy data science machine learningif want break cutting edge ai  course help  deep learning engineers highly sought  mastering deep learning give numerous new career opportunities  deep learning also new  superpower  let build ai systems possible years ago    course  learn foundations deep learning  finish class     understand major technology trends driving deep learning   able build  train apply fully connected deep neural networks    know implement efficient  vectorized  neural networks    understand key parameters neural network architecture   course also teaches deep learning actually works  rather presenting cursory surface level description  completing  able apply deep learning applications  looking job ai  course also able answer basic interview questions    first course deep learning specialization ',
#  'securing investment returns long runasset management  investment  stock  fintech  sustainability  leadership management  rate return  valuation  finance   finance  investment management business financein course  learn famous dichotomy active passive investing  appropriately measure analyze investment performance future trends investment management industry   first learn absolute relative performance  risk adjusted returns decompose investment performance  focus shift two main categories investment vehicles  active passive funds  entail terms expected performance  finally  explore worlds sustainable finance  neurofinance fintech  three areas research shape future investment management industry   also benefit insights experts ubs  corporate partner  practical implementation various concepts develop course ',
#  'cloud computing concepts  part 2distributed computing  file system  wireless sensor network  sensor network  deadlock  elections  cloud computing  clustered file system  mutual exclusion  distributed file systems computer science algorithmscloud computing systems today  whether open source used inside companies  built using common set core techniques  algorithms  design philosophies   centered around distributed systems  learn fundamental distributed computing  concepts  cloud computing    concepts include  clouds  mapreduce  key value nosql stores  classical distributed algorithms  widely used distributed algorithms  scalability  trending areas  much  much     know systems work inside  get hands dirty using concepts provided homework exercises  programming assignments  implement concepts template code  programs  provided c   programming language  prior experience c   required    course also features interviews leading researchers managers  industry academia   course builds material covered cloud computing concepts  part 1 course ',
#  'introduction systems biologybios  molecular biology  systems biology  biology  analysis  proteomics  computational biology  biochemistry   properties  bioinformatics life sciences basic sciencethis course introduce student contemporary systems biology focused mammalian cells  constituents functions  biology moving molecular modular  knowledge genome gene expression deepens develop lists molecules  proteins  lipids  ions  involved cellular processes  need understand molecules interact form modules act discrete functional systems  systems underlie core subcellular processes signal transduction  transcription  motility electrical excitability  turn processes come together exhibit cellular behaviors secretion  proliferation action potentials  properties subcellular cellular systems  mechanisms emergent behaviors systems arise  types experiments inform systems level thinking  need computation simulations understand systems   course develop multiple lines reasoning answer questions listed  two major reasoning threads  design  execution interpretation multivariable experiments produce large data sets  quantitative reasoning  models simulations  examples discussed demonstrate   cell  level functions arise   mechanistic knowledge allows us predict cellular behaviors leading disease states drug responses ',
#  'horse course  introduction basic care managementhuman learning  disease  behavior  animal behavior  anatomy  leadership management  disease management  animal  nutrition  horse care life sciences animal healththere 100 million horses  donkeys mules world today owners animals found almost every continent almost every society   horse course cover many unique aspects equine ownership touch upon science behind many today management practices ',
#  'innovation strategy  developing fintech strategyorganizational structure  strategic partnerships  strategy  hypercompetition  lecture  financial services companies  financial services  innovation  fintech  banking business business strategywelcome innovation strategy  developing fintech strategy  probably know  third course three part specialization focused digital transformation finance    course  aim bring insights business strategy intersects innovation finance  excited class look forward helping learn important topic   begin  recommend taking minutes explore course site  good place start navigation bar left  click course content see material cover week  well preview assignments need complete pass course  click discussions see forums discuss course material fellow students taking class  sure introduce everyone meet greet forum   course take four weeks complete  check recommended course schedule see quick overview lessons assignments complete week   time finish course  understood job fintech innovation strategy solve mastered internal external innovation tools solve problem  also exposed world leading financial companies work innovation seen inspirational examples digital masters  google  apple amazon  introduced capstone project specialization chance form preliminary solutions financial company needs think fintech innovation strategy   course primary focus banking sector  insurance secondary area concern  examples rooted north american european financial markets    good luck get started  look forward seeing class ',
#  'understanding cancer metastasissenescence  stemming  human learning  cancer  biology  cachexia  tumor  molecular biology  causality  cancer biology life sciences basic scienceover 500 000 people united states 8 million people worldwide dying cancer every year  people live longer  incidence cancer rising worldwide  disease expected strike 20 million people annually 2030   everyone  touched cancer way  lifetime  thanks years dedication commitment research made enormous advances prevention treatment cancer  still lot work done   course  physicians scientists johns hopkins school medicine explain cancer spreads metastasizes   describe major theories metastasis describe biology behind steps metastasis  course also describes major organs targeted metastasis describes metastases harm patient ',
#  'measuring success patient safety quality improvement project  patient safety vi safety  performance  patient safety  measurement  health system  data analysis  measure b  evaluation  categorization  performance measurement life sciences healthcare managementhow know patient safety quality project meeting objectives  peter drucker said  gets measured  gets managed   course  students learn measurement critical quality improvement work  equally important  learn data sources provide meaningful information tools locate  finally  students learn interpret data patient safety quality projects guide modify implementation maximize chances making difference patients ',
#  'building deep learning models tensorflowmachine learning  convolution  pytorch  artificial neural networks  recurrent neural network  unsupervised learning  human learning  deep learning  tensorflow  autoencoder data science machine learningthe majority data world unlabeled unstructured  shallow neural networks cannot easily capture relevant structure  instance  images  sound  textual data  deep networks capable discovering hidden structures within type data  course use tensorflow library apply deep learning different data types order solve real world problems  learning outcomes  completing course  learners able    texplain foundational tensorflow concepts main functions  operations execution pipelines     tdescribe tensorflow used curve fitting  regression  classification minimization error functions     tunderstand different types deep architectures  convolutional networks  recurrent networks autoencoders    tapply tensorflow backpropagation tune weights biases neural networks trained ',
#  ...]

# %% [markdown]
# #### lemmatisation

# %% [markdown]
# La lemmatisation est une technique de traitement du langage naturel (NLP) qui consiste à transformer les mots d'un texte en leur forme canonique ou de base, appelée lemme. Contrairement à la racine (ou stemming), qui découpe simplement la fin des mots pour trouver leur tronc commun, la lemmatisation utilise des connaissances sur la morphologie des mots et le contexte grammatical pour ramener chaque mot à son lemme.
#
# Exemple de lemmatisation:
# "playing" → "play",
# "better" → "good",
# "went" → "go",
# "cats" → "cat",

# %%
"""stemmed_words=[]
stemmer = PorterStemmer()
for i in range(data.shape[0]):
    elt=[stemmer.stem(word) for word in tags]
    elt=" ".join(elt)
    stemmed_words.append(elt)   
stemmed_words"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[154], line 4
#       2 stemmer = PorterStemmer()
#       3 for i in range(data.shape[0]):
# ----> 4     elt=[stemmer.stem(word) for word in tags]
#       5     elt=" ".join(elt)
#       6     stemmed_words.append(elt)
#
# Cell In[154], line 4, in <listcomp>(.0)
#       2 stemmer = PorterStemmer()
#       3 for i in range(data.shape[0]):
# ----> 4     elt=[stemmer.stem(word) for word in tags]
#       5     elt=" ".join(elt)
#       6     stemmed_words.append(elt)
#
# File ~\anaconda3\Lib\site-packages\nltk\stem\porter.py:675, in PorterStemmer.stem(self, word, to_lowercase)
#     673 stem = self._step3(stem)
#     674 stem = self._step4(stem)
# --> 675 stem = self._step5a(stem)
#     676 stem = self._step5b(stem)
#     678 return stem
#
# File ~\anaconda3\Lib\site-packages\nltk\stem\porter.py:633, in PorterStemmer._step5a(self, word)
#     631 if word.endswith("e"):
#     632     stem = self._replace_suffix(word, "e", "")
# --> 633     if self._measure(stem) > 1:
#     634         return stem
#     635     if self._measure(stem) == 1 and not self._ends_cvc(stem):
#
# File ~\anaconda3\Lib\site-packages\nltk\stem\porter.py:188, in PorterStemmer._measure(self, stem)
#     183 # Construct a string of 'c's and 'v's representing whether each
#     184 # character in `stem` is a consonant or a vowel.
#     185 # e.g. 'falafel' becomes 'cvcvcvc',
#     186 #      'architecture' becomes 'vcccvcvccvcv'
#     187 for i in range(len(stem)):
# --> 188     if self._is_consonant(stem, i):
#     189         cv_sequence += "c"
#     190     else:
#
# File ~\anaconda3\Lib\site-packages\nltk\stem\porter.py:126, in PorterStemmer._is_consonant(self, word, i)
#     122                 self.pool[val] = key
#     124     self.vowels = frozenset(["a", "e", "i", "o", "u"])
# --> 126 def _is_consonant(self, word, i):
#     127     """Returns True if word[i] is a consonant, False otherwise
#     128
#     129     A consonant is defined in the paper as follows:
#    (...)
#     136         is not a consonant it is a vowel.
#     137     """
#     138     if word[i] in self.vowels:
#
# KeyboardInterrupt:

# %%
data['tags']=tags

# %% [markdown]
# #### creation du dataframe a utiliser

# %%
usefull_df=data[["Course Name", 'tags']]
usefull_df.columns=['CourseName','Tags']

# %%
usefull_df
# Out:
#                                              CourseName  \
# 0     write a feature length screenplay for film or ...
# 1     business strategy  business model canvas analy...
# 2                         silicon thin film solar cells
# 3                                  finance for managers
# 4          retrieve data using single table sql queries
# ...                                                 ...
# 3517  capstone  retrieving  processing  and visualiz...
# 3518                   patrick henry  forgotten founder
# 3519  business intelligence and data analytics  gene...
# 3520                                rigid body dynamics
# 3521  architecting with google kubernetes engine  pr...
#
#                                                    Tags
# 0     write feature length screenplay film televisio...
# 1     business strategy  business model canvas analy...
# 2     silicon thin film solar cellschemistry  physic...
# 3     finance managersaccounts receivable  dupont an...
# 4     retrieve data using single table sql queriesda...
# ...                                                 ...
# 3517  capstone  retrieving  processing  visualizing ...
# 3518  patrick henry  forgotten founderretirement  ca...
# 3519  business intelligence data analytics  generate...
# 3520  rigid body dynamicsangular  mechanical design ...
# 3521  architecting google kubernetes engine  product...
#
# [3522 rows x 2 columns]

# %% [markdown]
# #### vectorisation du texte dans la colonne tags : ici nous puvons utiliser differentes methodes de vectorisation ; on essayera CountVectorizer et TfidfVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data['tags']).toarray()

cv=CountVectorizer(max_features=3522,stop_words='english')
cv=cv.fit_transform(data['tags']).toarray()

similarity_tfidf = cosine_similarity(X)
similarity_cv = cosine_similarity(cv)

# %%
similarity_tfidf.shape
# Out:
# (3522, 3522)

# %%
similarity_cv.shape
# Out:
# (3522, 3522)

# %% [markdown]
# ### ici nous definissons la fonction qui sera utilsée pour la recommendation

# %% [markdown]
# #### cas du CountVectorizer

# %%
def recommandation_cv(title):
    course = usefull_df[usefull_df['CourseName'] == title.lower()]
    if len(course)==0:
        print("ce cours n'existe pas")
    else:
        course_index=course.index[0]
        distances = similarity_cv[course_index]
        course_list = sorted(list(enumerate(distances)),reverse=True, key=lambda x:x[1])[1:11]

        for i in course_list:
            print(usefull_df.iloc[i[0]].CourseName)

# %% [markdown]
# ### cas du TfidfVectorizer

# %%
def recommandation_tfidf(title):
    course = usefull_df[usefull_df['CourseName'] == title.lower()]
    if len(course)==0:
        print("ce cours n'existe pas")
    else:
        course_index=course.index[0]
        distances = similarity_tfidf[course_index]
        course_list = sorted(list(enumerate(distances)),reverse=True, key=lambda x:x[1])[1:11]

        for i in course_list:
            print(usefull_df.iloc[i[0]].CourseName)

# %%
recommandation_tfidf("silicon thin film solar cells")
# Out:
# physics of silicon solar cells
# introduction to solar cells
# organic solar cells   theory and practice
# solar energy systems overview
# solar energy basics
# photovoltaic solar energy
# solar energy and electrical system design
# the science of the solar system
# solar energy codes  permitting and zoning
# origins   formation of the universe  solar system  earth and life

# %%
recommandation_cv("silicon thin film solar cells")
# Out:
# physics of silicon solar cells
# introduction to solar cells
# organic solar cells   theory and practice
# solar energy systems overview
# solar energy basics
# photovoltaic solar energy
# solar energy and electrical system design
# the science of the solar system
# solar energy codes  permitting and zoning
# origins   formation of the universe  solar system  earth and life

# %% [markdown]
# ## on remarque que pratiquement les memes livres sont recommandés: pour la suite on conservera le countvectorizer

# %% [markdown]
# # Deployement: dans cette section nous avons sauvegarder certains fichier necessaire pour le deployement de notre model a savoir
# - un fichier json contenant des index et nom  de cours
# - un fichier npy contenant les similarités calculées sur notre jeu de données
# - un fichier pkl contenant notre vocabulaire appris lors de la vectorisation

# %% [markdown]
# ### sauvegarde du fichier json contenant des index et nom de cours

# %%
import json

keys=[i for i in range(len(data))]
values=[usefull_df['CourseName'][i] for i in range(len(data))]
index_course_name = dict(zip(keys, values))

filename='index_course_name.json'
# Sauvegarde du dictionnaire dans un fichier JSON
with open(filename, 'w') as file:
    json.dump(index_course_name, file)
    
print(f"Le dictionnaire a été sauvegardé dans le fichier {filename}.")
# Out:
# Le dictionnaire a été sauvegardé dans le fichier index_course_name.json.

# %% [markdown]
# ### sauvegarde du fichier pkl contenant notre vocabulaire appris lors de la vectorisation des titres de cours

# %%
vectorizer=CountVectorizer(max_features=3522,stop_words='english')
cv_fited=vectorizer.fit(usefull_df['CourseName'])#(data['tags'])#.toarray()
import pickle
with open('vectorizer_fited.pkl','wb') as file:
    pickle.dump(cv_fited,file)

print("fichier sauvegardé.")
# Out:
# fichier sauvegardé.

# %% [markdown]
# ### sauvegarde pkl contenant les descriptions de differents cours vectorizer

# %%
description_transformed=cv_fited.transform(usefull_df['Tags']).toarray()

import pickle
with open('description_fit_transformed.pkl','wb') as file:
    pickle.dump(description_transformed,file)

print("fichier sauvegardé.")
# Out:
# fichier sauvegardé.

# %% [markdown]
# ### par la suite nous  chargerons  ces fichiers afin de les utiliser dans la fonction de recommandation utilisé lors du deploiement

# %%
with open("vectorizer_fited.pkl", 'rb') as file:
    loaded_vectorizer = pickle.load(file)

with open("description_fit_transformed.pkl", 'rb') as file:
    loaded_description = pickle.load(file)
    
with open("index_course_name.json", 'r') as file:
    loaded_dictionary = json.load(file)
    

def recommandation_deploy(title):
    title=title.split(" ")
    title=loaded_vectorizer.transform(title)
    similarities = cosine_similarity(title,loaded_description)
    indices_similaires = np.argsort(similarities[0])[::-1]
    indices_similaires=indices_similaires[:10]
    indices_similaires=[str(i) for i in indices_similaires]
    # Obtenir les cours des livres recommandés
    cours_recommandes = [loaded_dictionary[i] for i in indices_similaires]
    #livres_recommandes = [loaded_dictionary[str(2605)] ]
    print("Livres recommandés:", cours_recommandes)

# %%
recommandation_deploy("machine learning en python")
# Out:
# Livres recommandés: ['introduction to applied machine learning', 'how google does machine learning', 'optimizing machine learning performance', 'machine learning with h2o flow', 'machine translation', 'machine learning for data analysis', 'developing ai applications on azure', 'machine learning foundations  a case study approach', 'the power of machine learning  boost business  accumulate clicks  fight fraud  and deny deadbeats', 'machine learning for all']

# %%
recommandation_deploy("formation django pour debutant")
# Out:
# Livres recommandés: ['oceanography  a key to better understand our world', 'russian company law  formation of legal entities ', 'analyzing the universe', 'russian for beginners 2               a1', 'the music of the rolling stones  1962 1974', 'russian for beginners 3                a1', 'origins   formation of the universe  solar system  earth and life', 'bacteria and chronic infections', 'taxation of business entities i  corporations', 'getting started in cryo em']

# %%
recommandation_deploy("machine learning")
# Out:
# Livres recommandés: ['introduction to applied machine learning', 'how google does machine learning', 'optimizing machine learning performance', 'machine learning with h2o flow', 'machine translation', 'machine learning for data analysis', 'developing ai applications on azure', 'machine learning foundations  a case study approach', 'the power of machine learning  boost business  accumulate clicks  fight fraud  and deny deadbeats', 'machine learning for all']
